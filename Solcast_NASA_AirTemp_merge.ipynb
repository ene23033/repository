# %% [markdown]
# <a href="https://colab.research.google.com/github/ene23033/repository/blob/master/Solcast_NASA_AirTemp_merge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('/content/IITB-NASA data.csv')
df1.index = pd.to_datetime(df1['timestamp'], format='%d-%m-%Y %H:%M')
df1.head()
# Out:
#                             timestamp  ALLSKY_SFC_SW_DIFF  ALLSKY_SFC_SW_DNI  \
# timestamp
# 2015-03-01 00:00:00  01-03-2015 00:00                 0.0                0.0
# 2015-03-01 01:00:00  01-03-2015 01:00                 0.0                0.0
# 2015-03-01 02:00:00  01-03-2015 02:00                 0.0                0.0
# 2015-03-01 03:00:00  01-03-2015 03:00                 0.0                0.0
# 2015-03-01 04:00:00  01-03-2015 04:00                 0.0                0.0
#
#                      ALLSKY_SFC_SW_DWN    T2M  WS10M
# timestamp
# 2015-03-01 00:00:00                0.0  20.78   2.31
# 2015-03-01 01:00:00                0.0  20.66   2.44
# 2015-03-01 02:00:00                0.0  20.27   2.49
# 2015-03-01 03:00:00                0.0  20.08   2.76
# 2015-03-01 04:00:00                0.0  19.94   2.82

# %%
df2 = pd.read_csv('/content/POA_solcast_SCADA.csv')
df2.index = pd.to_datetime(df2['timestamp'], format='%d-%m-%Y %H:%M')
df2.head()
# Out:
#                      air_temp  azimuth  clearsky_dhi  clearsky_dni  \
# timestamp
# 2015-03-01 00:00:00        22       29             0             0
# 2015-03-01 00:05:00        22       24             0             0
# 2015-03-01 00:10:00        22       18             0             0
# 2015-03-01 00:15:00        22       12             0             0
# 2015-03-01 00:20:00        22        5             0             0
#
#                      clearsky_ghi  dewpoint_temp  dhi  dni  ghi  \
# timestamp
# 2015-03-01 00:00:00             0           18.2  0.0  0.0  0.0
# 2015-03-01 00:05:00             0           18.2  0.0  0.0  0.0
# 2015-03-01 00:10:00             0           18.2  0.0  0.0  0.0
# 2015-03-01 00:15:00             0           18.2  0.0  0.0  0.0
# 2015-03-01 00:20:00             0           18.1  0.0  0.0  0.0
#
#                      precipitation_rate  ...  zenith         timestamp  \
# timestamp                                ...
# ...

# %%
df3 = pd.merge(df1, df2, left_on=df1.index, right_on=df2.index, how='inner')

df3.to_csv('Merged file(Solcast-NASA).csv', index=False)

df3.tail()
# Out:
#                     key_0       timestamp_x  ALLSKY_SFC_SW_DIFF  \
# 12059 2016-09-01 13:00:00  01-09-2016 13:00              375.02
# 12060 2016-09-01 14:00:00  01-09-2016 14:00              297.19
# 12061 2016-09-01 15:00:00  01-09-2016 15:00              221.04
# 12062 2016-09-01 16:00:00  01-09-2016 16:00              172.44
# 12063 2016-09-01 17:00:00  01-09-2016 17:00               67.38
#
#        ALLSKY_SFC_SW_DNI  ALLSKY_SFC_SW_DWN    T2M  WS10M  air_temp  azimuth  \
# 12059             277.93             744.83  28.47   5.81        29      130
# 12060             240.88             629.70  28.29   5.69        29      108
# 12061             206.33             447.92  27.79   5.42        28       99
# 12062              80.22             241.35  27.09   4.84        28       93
# 12063              65.09              89.15  26.21   3.85        28       88
#
#        clearsky_dhi  ...  zenith       timestamp_y  Active_Power  Temp1  \
# ...
